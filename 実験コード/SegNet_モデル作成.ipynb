# %%
#GoogleDriveからマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#ライブラリインポート
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split

# %%
#データの読み込みとリサイズ
def load_and_resize_images(directory, img_height, img_width):
    images = []
    for filename in sorted(os.listdir(directory)):
        img = cv2.imread(os.path.join(directory, filename), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img_resized = cv2.resize(img, (img_width, img_height))
            img_resized = img_resized[..., np.newaxis]
            images.append(img_resized)
    return images

img_height, img_width = 128, 128

# 各データセットのディレクトリパスを指定
train_image_dir = "/content/drive/MyDrive/dataset_1000/実験/train/images"
train_mask_dir = "/content/drive/MyDrive/dataset_1000/実験/train/masks"

val_image_dir = "/content/drive/MyDrive/dataset_1000/実験/val/images"
val_mask_dir = "/content/drive/MyDrive/dataset_1000/実験/val/masks"

test_image_dir = "/content/drive/MyDrive/test/images"
test_mask_dir = "/content/drive/MyDrive/test/masks"

# 各データセットを読み込む
X_train = load_and_resize_images(train_image_dir, img_height, img_width)
y_train = load_and_resize_images(train_mask_dir, img_height, img_width)

X_val = load_and_resize_images(val_image_dir, img_height, img_width)
y_val = load_and_resize_images(val_mask_dir, img_height, img_width)

X_test = load_and_resize_images(test_image_dir, img_height, img_width)
y_test = load_and_resize_images(test_mask_dir, img_height, img_width)

# %%
# 画像とマスクの形状を変更

X_train = np.array(X_train)
y_train = np.array(y_train)

X_val = np.array(X_val)
y_val = np.array(y_val)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#正規化
# 画像とマスクの形状を変更し、正規化を行う（これはそのままでOK）
X_train = np.array(X_train) / 255.0
y_train = np.array(y_train) / 255.0
X_val = np.array(X_val) / 255.0
y_val = np.array(y_val) / 255.0
X_test = np.array(X_test) / 255.0
y_test = np.array(y_test) / 255.0

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model

def segnet_model(input_shape, num_classes):
    inputs = Input(input_shape)

    # エンコーダ部分
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    p1 = MaxPooling2D((2, 2))(c1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    p2 = MaxPooling2D((2, 2))(c2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    p3 = MaxPooling2D((2, 2))(c3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    p4 = MaxPooling2D((2, 2))(c4)

    # ボトルネック
    c5 = Conv2D(512, (3, 3), activation='relu', padding='same')(p4)

    # デコーダ部分
    u1 = UpSampling2D((2, 2))(c5)
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(u1)
    u2 = UpSampling2D((2, 2))(c6)
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(u2)
    u3 = UpSampling2D((2, 2))(c7)
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(u3)
    u4 = UpSampling2D((2, 2))(c8)
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(u4)

    # セグメンテーションマップを生成
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# モデルのインスタンス化
model = segnet_model(input_shape=(256, 256, 1), num_classes=2)  # 背景と数式の2クラス分類

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 64)      640
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 128)     73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 128)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 256)       295168
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 256)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 512)       1180160
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 512)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 512)       2359808
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 512)       0
#  D)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 512)       2359808
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 512)       0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 256)       1179904
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 256)     0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 128)     295040
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 128)     0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 64)      73792
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 1)       65
#
# =================================================================
# Total params: 7818241 (29.82 MB)
# Trainable params: 7818241 (29.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf

# IoU関数の定義
def iou(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    iou = intersection / union
    return iou

# 精度を計算する関数
def precision(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true_f * y_pred_f, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred_f, 0, 1)))
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    return precision

# 再現率を計算する関数
def recall(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true_f * y_pred_f, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true_f, 0, 1)))
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    return recall

# F1スコアを計算する関数
def f1_score(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    return 2 * ((p * r) / (p + r + tf.keras.backend.epsilon()))

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# モデルのコンパイル
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=[iou, precision, recall, f1_score])

# 早期停止のコールバックを設定
early_stopping = EarlyStopping(
    monitor='val_loss',  # 監視する指標
    patience=10,         # 10エポック改善がなければ停止
    verbose=1,           # 進行状況のメッセージ表示
    restore_best_weights=True  # 最良のモデルの重みを復元
)

# %%
# モデルのトレーニング（早期停止をコールバックとして追加）
history = model.fit(
    X_train, y_train,
    batch_size=32,
    epochs=50,  # 最大エポック数
    validation_data=(X_val, y_val),
    callbacks=[early_stopping]  # 早期停止のコールバックを追加
)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 26s 224ms/step - loss: 0.4276 - iou: 0.7352 - precision: 0.9045 - recall: 0.9610 - f1_score: 0.9145 - val_loss: 0.3479 - val_iou: 0.7829 - val_precision: 0.9048 - val_recall: 0.9995 - val_f1_score: 0.9496
# Epoch 2/50
# 25/25 [==============================] - 4s 169ms/step - loss: 0.3251 - iou: 0.8166 - precision: 0.9043 - recall: 0.9997 - f1_score: 0.9496 - val_loss: 0.3056 - val_iou: 0.8349 - val_precision: 0.9050 - val_recall: 0.9996 - val_f1_score: 0.9498
# Epoch 3/50
# 25/25 [==============================] - 5s 184ms/step - loss: 0.2891 - iou: 0.8292 - precision: 0.9041 - recall: 0.9994 - f1_score: 0.9493 - val_loss: 0.2700 - val_iou: 0.8256 - val_precision: 0.9046 - val_recall: 0.9992 - val_f1_score: 0.9493
# Epoch 4/50
# 25/25 [==============================] - 5s 183ms/step - loss: 0.2565 - iou: 0.8420 - precision: 0.9039 - recall: 0.9993 - f1_score: 0.9492 - val_loss: 0.2565 - val_iou: 0.8415 - val_precision: 0.9046 - val_recall: 0.9993 - val_f1_score: 0.9494
# Epoch 5/50
# 25/25 [==============================] - 5s 184ms/step - loss: 0.2505 - iou: 0.8447 - precision: 0.9039 - recall: 0.9993 - f1_score: 0.9492 - val_loss: 0.2506 - val_iou: 0.8296 - val_precision: 0.9043 - val_recall: 0.9989 - val_f1_score: 0.9491
# Epoch 6/50
# 25/25 [==============================] - 5s 186ms/step - loss: 0.2406 - iou: 0.8462 - precision: 0.9039 - recall: 0.9992 - f1_score: 0.9491 - val_loss: 0.2446 - val_iou: 0.8549 - val_precision: 0.9046 - val_recall: 0.9993 - val_f1_score: 0.9494
# Epoch 7/50
# 25/25 [==============================] - 5s 186ms/step - loss: 0.2351 - iou: 0.8503 - precision: 0.9039 - recall: 0.9992 - f1_score: 0.9491 - val_loss: 0.2399 - val_iou: 0.8421 - val_precision: 0.9043 - val_recall: 0.9989 - val_f1_score: 0.9491
# Epoch 8/50
# 25/25 [==============================] - 5s 186ms/step - loss: 0.2329 - iou: 0.8495 - precision: 0.9038 - recall: 0.9992 - f1_score: 0.9491 - val_loss: 0.2383 - val_iou: 0.8510 - val_precision: 0.9045 - val_recall: 0.9991 - val_f1_score: 0.9492
# Epoch 9/50
# 25/25 [==============================] - 5s 188ms/step - loss: 0.2289 - iou: 0.8536 - precision: 0.9038 - recall: 0.9991 - f1_score: 0.9490 - val_loss: 0.2375 - val_iou: 0.8566 - val_precision: 0.9044 - val_recall: 0.9990 - val_f1_score: 0.9492
# Epoch 10/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.2249 - iou: 0.8553 - precision: 0.9038 - recall: 0.9991 - f1_score: 0.9490 - val_loss: 0.2317 - val_iou: 0.8458 - val_precision: 0.9042 - val_recall: 0.9988 - val_f1_score: 0.9490
# Epoch 11/50
# 25/25 [==============================] - 5s 189ms/step - loss: 0.2205 - iou: 0.8557 - precision: 0.9037 - recall: 0.9990 - f1_score: 0.9489 - val_loss: 0.2364 - val_iou: 0.8676 - val_precision: 0.9045 - val_recall: 0.9991 - val_f1_score: 0.9492
# Epoch 12/50
# 25/25 [==============================] - 5s 190ms/step - loss: 0.2169 - iou: 0.8608 - precision: 0.9037 - recall: 0.9990 - f1_score: 0.9490 - val_loss: 0.2205 - val_iou: 0.8601 - val_precision: 0.9043 - val_recall: 0.9988 - val_f1_score: 0.9490
# Epoch 13/50
# 25/25 [==============================] - 5s 193ms/step - loss: 0.2098 - iou: 0.8632 - precision: 0.9060 - recall: 0.9976 - f1_score: 0.9496 - val_loss: 0.2149 - val_iou: 0.8671 - val_precision: 0.9132 - val_recall: 0.9920 - val_f1_score: 0.9508
# Epoch 14/50
# 25/25 [==============================] - 4s 179ms/step - loss: 0.2004 - iou: 0.8710 - precision: 0.9242 - recall: 0.9855 - f1_score: 0.9538 - val_loss: 0.2056 - val_iou: 0.8583 - val_precision: 0.9360 - val_recall: 0.9666 - val_f1_score: 0.9510
# Epoch 15/50
# 25/25 [==============================] - 5s 193ms/step - loss: 0.1912 - iou: 0.8748 - precision: 0.9299 - recall: 0.9828 - f1_score: 0.9556 - val_loss: 0.2003 - val_iou: 0.8645 - val_precision: 0.9342 - val_recall: 0.9733 - val_f1_score: 0.9533
# Epoch 16/50
# 25/25 [==============================] - 5s 195ms/step - loss: 0.1827 - iou: 0.8811 - precision: 0.9347 - recall: 0.9823 - f1_score: 0.9578 - val_loss: 0.1985 - val_iou: 0.8897 - val_precision: 0.9270 - val_recall: 0.9870 - val_f1_score: 0.9560
# Epoch 17/50
# 25/25 [==============================] - 5s 194ms/step - loss: 0.1803 - iou: 0.8841 - precision: 0.9354 - recall: 0.9831 - f1_score: 0.9585 - val_loss: 0.1905 - val_iou: 0.8773 - val_precision: 0.9326 - val_recall: 0.9819 - val_f1_score: 0.9566
# Epoch 18/50
# 25/25 [==============================] - 5s 193ms/step - loss: 0.1716 - iou: 0.8891 - precision: 0.9400 - recall: 0.9821 - f1_score: 0.9605 - val_loss: 0.1881 - val_iou: 0.8880 - val_precision: 0.9293 - val_recall: 0.9870 - val_f1_score: 0.9573
# Epoch 19/50
# 25/25 [==============================] - 5s 192ms/step - loss: 0.1672 - iou: 0.8910 - precision: 0.9410 - recall: 0.9832 - f1_score: 0.9616 - val_loss: 0.1900 - val_iou: 0.8922 - val_precision: 0.9332 - val_recall: 0.9840 - val_f1_score: 0.9579
# Epoch 20/50
# 25/25 [==============================] - 5s 194ms/step - loss: 0.1700 - iou: 0.8910 - precision: 0.9408 - recall: 0.9830 - f1_score: 0.9613 - val_loss: 0.1839 - val_iou: 0.8839 - val_precision: 0.9383 - val_recall: 0.9783 - val_f1_score: 0.9578
# Epoch 21/50
# 25/25 [==============================] - 5s 191ms/step - loss: 0.1602 - iou: 0.8961 - precision: 0.9446 - recall: 0.9823 - f1_score: 0.9630 - val_loss: 0.1911 - val_iou: 0.8961 - val_precision: 0.9281 - val_recall: 0.9894 - val_f1_score: 0.9577
# Epoch 22/50
# 25/25 [==============================] - 5s 190ms/step - loss: 0.1598 - iou: 0.8974 - precision: 0.9434 - recall: 0.9844 - f1_score: 0.9634 - val_loss: 0.1842 - val_iou: 0.8859 - val_precision: 0.9415 - val_recall: 0.9739 - val_f1_score: 0.9574
# Epoch 23/50
# 25/25 [==============================] - 4s 181ms/step - loss: 0.1609 - iou: 0.8964 - precision: 0.9444 - recall: 0.9829 - f1_score: 0.9631 - val_loss: 0.1816 - val_iou: 0.8766 - val_precision: 0.9386 - val_recall: 0.9789 - val_f1_score: 0.9583
# Epoch 24/50
# 25/25 [==============================] - 5s 190ms/step - loss: 0.1514 - iou: 0.9001 - precision: 0.9487 - recall: 0.9826 - f1_score: 0.9653 - val_loss: 0.1899 - val_iou: 0.9011 - val_precision: 0.9336 - val_recall: 0.9859 - val_f1_score: 0.9590
# Epoch 25/50
# 25/25 [==============================] - 4s 178ms/step - loss: 0.1435 - iou: 0.9076 - precision: 0.9514 - recall: 0.9830 - f1_score: 0.9669 - val_loss: 0.1801 - val_iou: 0.8875 - val_precision: 0.9430 - val_recall: 0.9731 - val_f1_score: 0.9578
# Epoch 26/50
# 25/25 [==============================] - 5s 190ms/step - loss: 0.1372 - iou: 0.9107 - precision: 0.9538 - recall: 0.9833 - f1_score: 0.9683 - val_loss: 0.1855 - val_iou: 0.9005 - val_precision: 0.9366 - val_recall: 0.9828 - val_f1_score: 0.9591
# Epoch 27/50
# 25/25 [==============================] - 5s 190ms/step - loss: 0.1336 - iou: 0.9134 - precision: 0.9557 - recall: 0.9829 - f1_score: 0.9690 - val_loss: 0.1829 - val_iou: 0.8844 - val_precision: 0.9465 - val_recall: 0.9673 - val_f1_score: 0.9568
# Epoch 28/50
# 25/25 [==============================] - 5s 189ms/step - loss: 0.1339 - iou: 0.9129 - precision: 0.9554 - recall: 0.9832 - f1_score: 0.9690 - val_loss: 0.1902 - val_iou: 0.9012 - val_precision: 0.9383 - val_recall: 0.9799 - val_f1_score: 0.9586
# Epoch 29/50
# 25/25 [==============================] - 5s 191ms/step - loss: 0.1241 - iou: 0.9186 - precision: 0.9591 - recall: 0.9835 - f1_score: 0.9711 - val_loss: 0.1878 - val_iou: 0.8983 - val_precision: 0.9441 - val_recall: 0.9720 - val_f1_score: 0.9579
# Epoch 30/50
# 25/25 [==============================] - 5s 192ms/step - loss: 0.1191 - iou: 0.9223 - precision: 0.9616 - recall: 0.9834 - f1_score: 0.9723 - val_loss: 0.1949 - val_iou: 0.8996 - val_precision: 0.9459 - val_recall: 0.9695 - val_f1_score: 0.9576
# Epoch 31/50
# 25/25 [==============================] - 5s 191ms/step - loss: 0.1202 - iou: 0.9213 - precision: 0.9615 - recall: 0.9827 - f1_score: 0.9719 - val_loss: 0.1992 - val_iou: 0.9052 - val_precision: 0.9420 - val_recall: 0.9764 - val_f1_score: 0.9589
# Epoch 32/50
# 25/25 [==============================] - 5s 190ms/step - loss: 0.1127 - iou: 0.9267 - precision: 0.9643 - recall: 0.9838 - f1_score: 0.9739 - val_loss: 0.1951 - val_iou: 0.9005 - val_precision: 0.9452 - val_recall: 0.9705 - val_f1_score: 0.9577
# Epoch 33/50
# 25/25 [==============================] - 5s 193ms/step - loss: 0.1067 - iou: 0.9299 - precision: 0.9667 - recall: 0.9836 - f1_score: 0.9751 - val_loss: 0.1914 - val_iou: 0.8970 - val_precision: 0.9492 - val_recall: 0.9643 - val_f1_score: 0.9567
# Epoch 34/50
# 25/25 [==============================] - 5s 191ms/step - loss: 0.1015 - iou: 0.9330 - precision: 0.9689 - recall: 0.9839 - f1_score: 0.9763 - val_loss: 0.2076 - val_iou: 0.9078 - val_precision: 0.9432 - val_recall: 0.9751 - val_f1_score: 0.9589
# Epoch 35/50
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - iou: 0.9372 - precision: 0.9710 - recall: 0.9846 - f1_score: 0.9778Restoring model weights from the end of the best epoch: 25.
# 25/25 [==============================] - 5s 181ms/step - loss: 0.0956 - iou: 0.9372 - precision: 0.9710 - recall: 0.9846 - f1_score: 0.9778 - val_loss: 0.2235 - val_iou: 0.9098 - val_precision: 0.9377 - val_recall: 0.9803 - val_f1_score: 0.9585
# Epoch 35: early stopping

# %%
import matplotlib.pyplot as plt
# 学習のロスと評価指標の履歴をプロット
plt.figure(figsize=(20, 4))

# ロスの履歴をプロット
plt.subplot(1, 5, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')

# IoUの履歴をプロット
plt.subplot(1, 5, 2)
plt.plot(history.history['iou'], label='Training IoU')
plt.plot(history.history['val_iou'], label='Validation IoU')
plt.legend()
plt.title('IoU')

# 精度の履歴をプロット
plt.subplot(1, 5, 3)
plt.plot(history.history['precision'], label='Training Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.legend()
plt.title('Precision')

# 再現率の履歴をプロット
plt.subplot(1, 5, 4)
plt.plot(history.history['recall'], label='Training Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.legend()
plt.title('Recall')

# F1スコアの履歴をプロット（オプショナル）
plt.subplot(1, 5, 5)
plt.plot(history.history['f1_score'], label='Training F1 Score')
plt.plot(history.history['val_f1_score'], label='Validation F1 Score')
plt.legend()
plt.title('F1 Score')

plt.tight_layout()

# グラフを保存
plt.savefig('training_graphs.png')

plt.show()

# %%
import os
from tensorflow.keras.models import Model

# 保存先のフォルダパスを指定
save_dir = '/content/drive/MyDrive/dataset_1000/model'

# 指定したフォルダが存在しない場合は作成
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# モデルの保存先のパスを指定
model_save_path = os.path.join(save_dir, 'segnet_1000_低解像度_model.h5')

# モデルをHDF5形式で保存
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
predictions = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 235ms/step

# %%
threshold = 0.5
predictions_t = (predictions > threshold).astype(np.uint8)

# %%
import matplotlib.pyplot as plt

idx = 0  # 表示する画像のインデックス

plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.imshow(X_test[idx])
plt.title("Original Image")

plt.subplot(1, 3, 2)
plt.imshow(y_test[idx].squeeze(), cmap='gray')
plt.title("True Mask")

plt.subplot(1, 3, 3)
plt.imshow(predictions_t[idx].squeeze(), cmap='gray')
plt.title("Predicted Mask")

plt.tight_layout()
plt.savefig('result.png')
plt.show()
